# %%
# %cd /home/agx/agro_sky_ai/AgroSkyAI/models/yolov7
# Out:
# /home/agx/agro_sky_ai/AgroSkyAI/models/yolov7

# %%
# !python detect.py --weights runs/train/fold1/weights/best.pt --source ../predict --conf 0.15 --img-size 512 --save-txt --save-conf --name predict_test
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.15, device='', exist_ok=False, img_size=512, iou_thres=0.45, name='predict_test', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='../predict', update=False, view_img=False, weights=['runs/train/fold1/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.85546875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %%
# !python detect.py --weights runs/train/fold2/weights/best.pt --source ../predict --conf 0.15 --img-size 512 --save-txt --save-conf --name predict_fold2_conf0.25
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.15, device='', exist_ok=False, img_size=512, iou_thres=0.45, name='predict_fold2_conf0.15', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='../predict', update=False, view_img=False, weights=['runs/train/fold2/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.85546875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python test.py --weights runs/train/fold1/weights/best.pt --data data/my_data.yaml --batch-size 16 --img-size 512 --conf-thres 0.5 --iou-thres 0.5 --task test --device 0 --save-json --name fold1_test_metrics_iou0.5 --save-txt --save-conf
# Out:
# Namespace(augment=False, batch_size=16, conf_thres=0.5, data='data/my_data.yaml', device='0', exist_ok=False, img_size=512, iou_thres=0.5, name='fold1_test_metrics_iou0.5', no_trace=False, project='runs/test', save_conf=True, save_hybrid=False, save_json=True, save_txt=True, single_cls=False, task='test', v5_metric=False, verbose=False, weights=['runs/train/fold1/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python test.py --weights runs/train/fold2/weights/best.pt --data data/fold2.yaml --batch-size 16 --img-size 512 --conf-thres 0.5 --iou-thres 0.5 --task test --device 0 --save-json --name fold2_test_metrics_iou0.5 --save-txt --save-conf
# Out:
# Namespace(augment=False, batch_size=16, conf_thres=0.5, data='data/fold2.yaml', device='0', exist_ok=False, img_size=512, iou_thres=0.5, name='fold2_test_metrics_iou0.5', no_trace=False, project='runs/test', save_conf=True, save_hybrid=False, save_json=True, save_txt=True, single_cls=False, task='test', v5_metric=False, verbose=False, weights=['runs/train/fold2/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python detect.py --weights runs/train/fold2/weights/best.pt --source ../fold2/test/images --conf 0.5 --img-size 512 --iou-thres 0.5 --save-txt --save-conf --name fold2_detect_results_conf0.5
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=512, iou_thres=0.5, name='fold2_detect_results_conf0.5', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='../fold2/test/images', update=False, view_img=False, weights=['runs/train/fold2/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python detect.py --weights runs/train/fold2/weights/best.pt --source ../predict --conf 0.25 --img-size 512 --save-txt --save-conf --name predict_fold2_conf0.25
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=512, iou_thres=0.45, name='predict_fold2_conf0.25', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='../predict', update=False, view_img=False, weights=['runs/train/fold2/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python detect.py --weights runs/train/fold2/weights/best.pt --source ../predict --conf 0.5 --img-size 512 --save-txt --save-conf --name predict_fold2_conf0.5
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=512, iou_thres=0.45, name='predict_fold2_conf0.5', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='../predict', update=False, view_img=False, weights=['runs/train/fold2/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
