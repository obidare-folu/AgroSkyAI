# %%
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %%
# !wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"

# %%
# %cd /home/agx/agro_sky_ai/AgroSkyAI/models/yolov7
# Out:
# /home/agx/agro_sky_ai/AgroSkyAI/models/yolov7

# %%
# %pwd
# Out:
# '/home/agx/agro_sky_ai/AgroSkyAI/models/yolov7'

# %%
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 60 --data data/my_data.yaml --weights yolov7.pt --device 0 --cache-images --name fold1 --img-size 512 --resume
# Out:
# Resuming training from ./runs/train/fold1/weights/last.pt
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='data/my_data.yaml', device='0', entity=None, epochs=60, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[500, 500], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='fold1', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/fold1', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='./runs/train/fold1/weights/last.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 30 --data data/fold2.yaml --weights runs/train/fold1/weights/best.pt --device 0 --cache-images --name fold2 --img-size 512 --hyp data/hyp.fold2.yaml --adam
# Out:
# Resuming training from ./runs/train/fold2/weights/last.pt
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.85546875MB)
#
# Namespace(adam=True, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='data/fold2.yaml', device='0', entity=None, epochs=30, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.fold2.yaml', image_weights=False, img_size=[512, 512], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='fold2', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/fold2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='./runs/train/fold2/weights/last.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 30 --data data/fold3_data.yaml --weights runs/train/fold2/weights/best.pt --device 0 --cache-images --name fold3 --img-size 576 --hyp data/hyp.fold3.yaml --adam --image-weights --resume
# Out:
# Resuming training from ./runs/train/fold3/weights/last.pt
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Namespace(adam=True, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='data/fold3_data.yaml', device='0', entity=None, epochs=30, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.fold3.yaml', image_weights=True, img_size=[576, 576], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='fold3', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/fold3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='./runs/train/fold3/weights/last.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights runs/train/fold1/weights/best.pt --source ../fold1/test/images --conf 0.5 --img-size 512 --save-txt --save-conf --name fold1_test_results
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=512, iou_thres=0.45, name='fold1_test_results', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='../fold1/test/images', update=False, view_img=False, weights=['runs/train/fold1/weights/best.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.1.0a0+41361538.nv23.06 CUDA:0 (Xavier, 30990.859375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/agx/agro_sky_ai/AgroSkyAI/agro_venv/lib/python3.8/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3490.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
python detect.py --weights runs/train/fold1/weights/best.pt --source 0 --conf 0.15 --img-size 512 --save-txt --save-conf --name fold1_camera_trial1
